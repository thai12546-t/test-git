# %% [markdown]
# ## Họ và tên : Trần Anh Thái
# ## MSSV : 22H1320007

# %% [markdown]
# ## 1. Nạp dự liệu iris vào bộ nhớ và hiển thị thông tin về số thuộc tính (dimensionality), số objects (size).

# %%
from sklearn.datasets import load_wine
import pandas as pd

wine = load_wine()
df = pd.DataFrame(data=wine.data, columns= wine.feature_names)
print(df.shape)
print(df.sample(3))
# Out:
# (178, 13)
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 111    12.52        2.43  2.17               21.0       88.0           2.55
# 150    13.50        3.12  2.62               24.0      123.0           1.40
# 103    11.82        1.72  1.88               19.5       86.0           2.50
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 111        2.27                  0.26             1.22             2.00  0.90
# 150        1.57                  0.22             1.25             8.60  0.59
# 103        1.64                  0.37             1.42             2.06  0.94
#
#      od280/od315_of_diluted_wines  proline
# 111                          2.78    325.0
# 150                          1.30    500.0
# 103                          2.44    415.0

# %% [markdown]
# ## 2. Đặt nhãn (label) cho dữ liệu đã nạp và hiển thị số lớp (classes)

# %%
labels = wine.target_names
feature_names = wine.feature_names
print(f'Number of classes : {len(labels)}')
print(labels)

print(f'Number of Features : {len(feature_names)}')
print(feature_names)
# Out:
# Number of classes : 3
# ['class_0' 'class_1' 'class_2']
# Number of Features : 13
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %% [markdown]
# ## 3. Tách dữ liệu thành hai phần: training data(70%) và test data (30%)

# %%
from sklearn.model_selection import train_test_split

X = df[feature_names]
Y = wine.target
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, train_size=0.7, test_size=0.3)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
print(X_train.head(3))
print(X_test.head(3))
# Out:
# (124, 13) (124,)
# (54, 13) (54,)
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 22     13.71        1.86  2.36               16.6      101.0           2.61
# 108    12.22        1.29  1.94               19.0       92.0           2.36
# 175    13.27        4.28  2.26               20.0      120.0           1.59
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 22         2.88                  0.27             1.69              3.8  1.11
# 108        2.04                  0.39             2.08              2.7  0.86
# 175        0.69                  0.43             1.35             10.2  0.59
#
#      od280/od315_of_diluted_wines  proline
# 22                           4.00   1035.0
# 108                          3.02    312.0
# 175                          1.56    835.0
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 54     13.74        1.67  2.25               16.4      118.0           2.60
# 151    12.79        2.67  2.48               22.0      112.0           1.48
# 63     12.37        1.13  2.16               19.0       87.0           3.50
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 54         2.90                  0.21             1.62             5.85  0.92
# 151        1.36                  0.24             1.26            10.80  0.48
# 63         3.10                  0.19             1.87             4.45  1.22
#
#      od280/od315_of_diluted_wines  proline
# 54                           3.20   1060.0
# 151                          1.47    480.0
# 63                           2.87    420.0

# %% [markdown]
# ## 4. Chuẩn hóa dữ liệu với StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
print(X_train[:3])
# Out:
# [[ 0.91083058 -0.46259897 -0.01142613 -0.82067872  0.06241693  0.58820446
#    0.93565436 -0.7619138   0.13007174 -0.51238741  0.65706596  1.94354495
#    0.93700997]
#  [-0.95609928 -0.96608672 -1.53725357 -0.14748691 -0.55401928  0.16998569
#    0.07243241  0.20791318  0.78462633 -0.98210744 -0.40859506  0.58118003
#   -1.41336684]
#  [ 0.35952243  1.67501572 -0.37471838  0.13300967  1.36378226 -1.11812811
#   -1.31488858  0.53118883 -0.44056558  2.22052913 -1.55950896 -1.44846566
#    0.28683658]]

# %% [markdown]
# ## 5. Tạo và huấn luyện mô hình với training data

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=0)
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %% [markdown]
# ## 6. Test và đánh giá độ chính xác của mô mình, yêu cầu hiển thị ma trận confusion matrix, accuracy, f-score

# %%
print(f'Input : {str(X_test[:9])}')
print(f'Output : {str(clf.predict(X_test[:9]))}')
print(f'True values : {str(Y_test[:9])}')
# Out:
# Input : [[ 0.83839434 -0.52438266 -0.46107997 -1.114466    1.42732176  0.32765089
#    0.709496   -1.17251987  0.15584179  0.29449026 -0.19412211  0.83138702
#    0.95291816]
#  [-0.3009336   0.41605785  0.39236462  0.94930938  0.97790266 -1.3361884
#   -0.78006944 -0.93207909 -0.5569969   2.50875878 -2.27175334 -1.71011086
#   -0.81391802]
#  [-0.80463648 -1.03222054 -0.79503655 -0.15628458 -0.8946769   1.66466461
#    0.90294605 -1.33281373  0.65086867 -0.33176751  1.22244464  0.34659262
#   -0.99669418]
#  [ 0.62252168 -0.46795623  0.31815205  0.3965124   1.27751539  0.86245638
#    0.59342596 -1.2526668   1.79933101  0.47342105  0.08919124  0.58164445
#    1.13569432]
#  [ 0.01088247  3.35963665 -0.90635541  0.76504372 -0.96958009  0.35736231
#    0.46768343 -0.45119752  0.92808371 -1.15932241 -1.09128105  0.68447963
#   -1.11854495]
#  [-1.77606345 -0.16701527  3.17533611  3.34476294  1.50222494  1.18928196
#    2.81810162  0.91130025  0.65086867  0.3615893  -0.14690322  1.55123324
#   -0.85961206]
#  [ 1.22216796 -0.07297122  0.87474635 -0.67222842  1.6520313   0.32765089
#    0.33226839 -0.37105059 -0.57679798 -0.06337132  0.46694237  1.38963511
#    1.66879145]
#  [-0.8166294   1.50696884  0.02130176  0.58077806 -0.81977372 -0.11802035
#   -1.20565957  1.15174104 -0.99262055  1.09967881 -1.8940022  -1.54851273
#   -0.69206725]
#  [-0.94855158 -0.46795623 -0.94346169 -0.15628458 -1.41899918 -1.08364137
#   -0.13201175  0.10983098  0.17564287 -0.80146083  0.18362902  0.7873148
#   -0.72252995]]
# Output : [0 2 0 0 1 0 0 2 1]
# True values : [0 2 1 0 1 1 0 2 1]

# %%
from sklearn.metrics import confusion_matrix
Y_pred = clf.predict(X_test)
Y_true = Y_test
print(f'Confusion Matrix : {confusion_matrix(Y_true, Y_pred)}')
# Out:
# Confusion Matrix : [[18  1  0]
#  [ 4 17  1]
#  [ 0  0 13]]

# %%
from sklearn.metrics import accuracy_score, f1_score
print(f'Accuracy : {accuracy_score(Y_true, Y_pred)}')
print(f'F1 Score : {f1_score(Y_true, Y_pred, average=None)}')
# Out:
# Accuracy : 0.8888888888888888
# F1 Score : [0.87804878 0.85       0.96296296]

# %% [markdown]
# ## 7. Trực quan hóa cây quyết định

# %%
import graphviz
from sklearn import tree 
dot_data = tree.export_graphviz(clf, out_file=None, feature_names=wine.feature_names, class_names=labels, filled=True, rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph
